# %%
#importing libraries
import pandas as pd
import numpy as np

df = pd.read_csv("student-mat.csv")
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# observing the final grade of students
df['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.shape
# Out:
# (395, 33)

# %%
df.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
df.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
# finding the ratio of males and females
m_students = len(df[df["sex"]=='M'])
f_students = len(df[df["sex"]=='F'])

print(" no. of male students : ", m_students)
print(" no. of female students : ", f_students)
# Out:
#  no. of male students :  187
#  no. of female students :  208

# %%
# displaying the overall percentage of individuals
percent = m_students/f_students*100
print(percent)
# Out:
# 89.90384615384616

# %%
# find the grade average of all the grades for each student
df['gradeavg'] = (df['G1']+df['G2']+ df['G3'])/3
df['gradeavg']
# Out:
# 0       5.666667
# 1       5.333333
# 2       8.333333
# 3      14.666667
# 4       8.666667
#          ...
# 390     9.000000
# 391    15.333333
# 392     8.333333
# 393    11.000000
# 394     8.666667
# Name: gradeavg, Length: 395, dtype: float64

# %%
df['sex']=df['sex'].replace({'F':1, 'M':0})
df
# Out:
#     school  sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP    1   18       U     GT3       A     4     4   at_home   teacher
# 1       GP    1   17       U     GT3       T     1     1   at_home     other
# 2       GP    1   15       U     LE3       T     1     1   at_home     other
# 3       GP    1   15       U     GT3       T     4     2    health  services
# 4       GP    1   16       U     GT3       T     3     3     other     other
# ..     ...  ...  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS    0   20       U     LE3       A     2     2  services  services
# 391     MS    0   17       U     LE3       T     3     1  services  services
# 392     MS    0   21       R     GT3       T     1     1     other     other
# 393     MS    0   18       R     LE3       T     3     2  services     other
# 394     MS    0   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# gradeavg      54
# dtype: int64

# %%
# creating a grading system

def define_grade(df):
    grades = []
    for row in df['gradeavg']:
        if row >= (0.9 * df['gradeavg'].max()):
            grades.append('A+')
        elif row >= (0.7 * df['gradeavg'].max()):
            grades.append('A')
        elif row < (0.7 * df['gradeavg'].max()):
            grades.append('B')
    df['grades'] = grades
    return df

# %%
# displaying the grade using define
df = define_grade(df)
df.head()
# Out:
#   school  sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP    1   18       U     GT3       A     4     4  at_home   teacher
# 1     GP    1   17       U     GT3       T     1     1  at_home     other
# 2     GP    1   15       U     LE3       T     1     1  at_home     other
# 3     GP    1   15       U     GT3       T     4     2   health  services
# 4     GP    1   16       U     GT3       T     3     3    other     other
#
#    ... goout Dalc  Walc  health  absences  G1  G2  G3   gradeavg grades
# 0  ...     4    1     1       3         6   5   6   6   5.666667      B
# 1  ...     3    1     1       3         4   5   5   6   5.333333      B
# 2  ...     2    2     3       3        10   7   8  10   8.333333      B
# 3  ...     2    1     1       5         2  15  14  15  14.666667      A
# 4  ...     2    1     2       5         4   6  10  10   8.666667      B
#
# [5 rows x 35 columns]

# %%
# analysing the data
df.describe()
# Out:
#               sex         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.526582   16.696203    2.749367    2.521519    1.448101    2.035443
# std      0.499926    1.276043    1.094735    1.088201    0.697505    0.839240
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%      0.000000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%      1.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%      1.000000   18.000000    4.000000    3.000000    2.000000    2.000000
# max      1.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.334177    3.944304    3.235443    3.108861    1.481013    2.291139
# ...

# %%
# now again observing the unique data
df.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# gradeavg      54
# grades         3
# dtype: int64

# %%
student_features = df.columns.tolist()
student_features.remove('grades')
student_features.remove('gradeavg')
student_features.remove('G1')
student_features.remove('G2')
student_features.remove('G3')
student_features
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences']

# %%
X = df[student_features].copy()
X.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.utils import shuffle

df = df[["G1", "G2", "G3", "studytime", "failures", "absences"]]
predict = "G3"

x = np.array(df.drop([predict], 1))
y = np.array(df[predict])

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)


linear_regression = LinearRegression()
linear_regression.fit(xtrain, ytrain)
# Out:
# <ipython-input-103-8fa205052d40>:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = np.array(df.drop([predict], 1))
# LinearRegression()

# %%
accuracy = linear_regression.score(xtest, ytest)
print(accuracy)
# Out:
# 0.8388269736346609

# %%
import matplotlib.pyplot as plt
# Histogram of grades
plt.hist(df['G3'], bins = 14, color='limegreen')
plt.xlabel('grade')
plt.ylabel('Count')
plt.title('Distribution of Final Grades')
# Out:
# Text(0.5, 1.0, 'Distribution of Final Grades')

# %%
import seaborn as sns
sns.lineplot(x="G3", y="G1" ,color='olive',data=df)
# Out:
# <Axes: xlabel='G3', ylabel='G1'>

# %%
df['G3'].value_counts()
# Out:
# 10    56
# 11    47
# 0     38
# 15    33
# 8     32
# 13    31
# 12    31
# 9     28
# 14    27
# 16    16
# 6     15
# 18    12
# 7      9
# 5      7
# 17     6
# 19     5
# 20     1
# 4      1
# Name: G3, dtype: int64

# %%
df['G1'].value_counts()
# Out:
# 10    51
# 8     41
# 11    39
# 7     37
# 12    35
# 13    33
# 9     31
# 14    30
# 15    24
# 6     24
# 16    22
# 18     8
# 17     8
# 5      7
# 19     3
# 4      1
# 3      1
# Name: G1, dtype: int64

# %%
plt.figure(figsize=(8,3))
plt.hist(df['failures'], bins = 14, color='fuchsia')
# Out:
# (array([312.,   0.,   0.,   0.,  50.,   0.,   0.,   0.,   0.,  17.,   0.,
#           0.,   0.,  16.]),
#  array([0.        , 0.21428571, 0.42857143, 0.64285714, 0.85714286,
#         1.07142857, 1.28571429, 1.5       , 1.71428571, 1.92857143,
#         2.14285714, 2.35714286, 2.57142857, 2.78571429, 3.        ]),
#  <BarContainer object of 14 artists>)

# %%
df['failures'].value_counts()
# Out:
# 0    312
# 1     50
# 2     17
# 3     16
# Name: failures, dtype: int64

# %%
plt.figure(figsize=(9,4))
plt.hist(df['studytime'], bins = 14, color='slategrey')
# Out:
# (array([105.,   0.,   0.,   0., 198.,   0.,   0.,   0.,   0.,  65.,   0.,
#           0.,   0.,  27.]),
#  array([1.        , 1.21428571, 1.42857143, 1.64285714, 1.85714286,
#         2.07142857, 2.28571429, 2.5       , 2.71428571, 2.92857143,
#         3.14285714, 3.35714286, 3.57142857, 3.78571429, 4.        ]),
#  <BarContainer object of 14 artists>)

# %%
plt.figure(figsize=(10,3))
sns.scatterplot(data=df, x = "studytime", y="failures", color="darkmagenta")
# Out:
# <Axes: xlabel='studytime', ylabel='failures'>

# %%
plt.figure(figsize=(18,4))
sns.lineplot(x="absences", y="failures" ,color='darkgreen',data=df)
# Out:
# <Axes: xlabel='absences', ylabel='failures'>

# %%
plt.figure(figsize=(10,4))
sns.boxenplot(data=df, x="absences",color="peru")
# Out:
# <Axes: xlabel='absences'>

# %%
plt.figure(figsize=(7,3))
sns.boxenplot(data=df, x="studytime",color="palegreen")
# Out:
# <Axes: xlabel='studytime'>
